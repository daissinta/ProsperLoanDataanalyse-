# %% [markdown]
# # Part II - (Prosper Loan Data Analysis)
# ## by (DAISSINTA BAIDI Sammy Salim)

# %% [markdown]
# ## Investigation Overview
#
# The purpose of this project is to put out  the characteristics of variables that can affect the loan status and to get some ideas about the relationships among multiple variables using  statistics and data visualizations. In this presentation we will use many visualisation will be created to study their relation with LoanStatus
#
# ## Dataset Overview
# our dataset contains 113,937 loans with 81 variables on each loan, including loan amount, borrower rate (or interest rate), current loan status, borrower income, and many others.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
# load in the dataset into a pandas dataframe
df_loan = pd.read_csv('prosperLoanData.csv')

# %% [markdown]
# ## (Visualization 1)

# %% [markdown]
# ### How is the distribution of LoanSatus?

# %%
type_order = df_loan['LoanStatus'].value_counts().index
sb.countplot(data = df_loan, x ='LoanStatus', color=sb.color_palette()[0], order=type_order)
plt.xlabel('LoanStatus')
plt.xticks(rotation =90)
plt.title('Counts of Loan Status')
plt.show()

# %% [markdown]
# ### observation
# from the distribution of LoanStatus feature we can observe that the Loan Status must hight is Current

# %% [markdown]
# ## (Visualization 2)

# %% [markdown]
# ### Relation between LoanOriginalAmount & LoanStatus

# %%
plt.figure(figsize = [20, 5])
sb.boxplot(data=df_loan,y='LoanOriginalAmount',x='LoanStatus',color=sb.color_palette()[4]);
plt.title('LoanOriginalAmount & LoanStatus');
plt.ylabel('Loan Original Amount($)');
plt.xlabel('Loan Status');
plt.xticks(rotation=15);

# %% [markdown]
# ### observation
# we note that completed , chargedoff have the lower IQR and current have the most higth IQR

# %% [markdown]
# ## (Visualization 3)
# correlation between LoanOriginalAmount, LoanOriginalAmount, StatedMonthlyIncome

# %%
plt.figure(figsize = [10, 5])
plt.scatter(data=df_loan,x='DebtToIncomeRatio',y = 'LoanStatus',c='LoanOriginalAmount',cmap = 'viridis_r')
plt.colorbar(label = 'LoanOriginalAmount');
plt.xlabel('DebtToIncomeRatio')
plt.ylabel('LoanStatus')
plt.title('LoanOriginalAmount vs LoanOriginalAmount  vs StatedMonthlyIncome');

# %% [markdown]
# ### Observation
# there are negative correlation between Debt To Income Ratio and Loan Status

# %%
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 418305 bytes to Part_II_slide_deck_template.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Part_II_slide_deck_template.slides.html
# Use Control-C to stop this server
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: x-www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: firefox: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: iceweasel: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: seamonkey: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: mozilla: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: epiphany: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: konqueror: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: chromium-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: google-chrome: not found
# ...
